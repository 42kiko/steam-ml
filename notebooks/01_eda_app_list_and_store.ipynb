# %% [markdown]
# # 01 - Initial EDA for Steam Web & Store data 📊
#
# This notebook performs a first exploratory data analysis (EDA) on the data that has been
# ingested so far:
#
# - `data/bronze/steam_web/app_list.parquet` - global Steam app list (appid, name, etc.).
# - `data/bronze/steam_store/app_details.parquet` - Steam Store app details (incremental).
#
# The goal is to get a feeling for data volume, schema, and a few basic distributions that we
# can later use for feature engineering and ML experiments.

# %% [markdown]
# ### Imports & Config

# %%
from pathlib import Path

import pandas as pd

# Assume this notebook lives in `notebooks/` under the project root.
PROJECT_ROOT = Path('..').resolve()
DATA_DIR = PROJECT_ROOT / 'data'
WEB_PARQUET = DATA_DIR / 'bronze' / 'steam_web' / 'app_list.parquet'
STORE_PARQUET = DATA_DIR / 'bronze' / 'steam_store' / 'app_details.parquet'
ALL_PARQUET = DATA_DIR / 'bronze' / 'steam_spy' / 'all.parquet'

WEB_PARQUET, STORE_PARQUET, ALL_PARQUET
# Out:
# (WindowsPath('C:/dev/steam-ml/data/bronze/steam_web/app_list.parquet'),
#  WindowsPath('C:/dev/steam-ml/data/bronze/steam_store/app_details.parquet'),
#  WindowsPath('C:/dev/steam-ml/data/bronze/steam_spy/all.parquet'))

# %% [markdown]
# ## 1. Steam Web app list

# %%
apps_df = pd.read_parquet(WEB_PARQUET)

print(apps_df.shape)

print(apps_df.info())

apps_df.head()
# Out:
# (208029, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208029 entries, 0 to 208028
# Data columns (total 4 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   appid                208029 non-null  int64
#  1   name                 208029 non-null  object
#  2   last_modified        208029 non-null  int64
#  3   price_change_number  208029 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 6.3+ MB
# None
#    appid                       name  last_modified  price_change_number
# 0     10             Counter-Strike     1745368572             32873429
# 1     20      Team Fortress Classic     1745368565             32873429
# 2     30              Day of Defeat     1745368580             32873429
# 3     40         Deathmatch Classic     1745368570             32873429
# 4     50  Half-Life: Opposing Force     1745368539             32873429

# %%
apps_df["last_modified"] = pd.to_datetime(
    apps_df["last_modified"],
    unit="s",
    utc=True,
)

apps_df
# Out:
#           appid                               name             last_modified  \
# 0            10                     Counter-Strike 2025-04-23 00:36:12+00:00
# 1            20              Team Fortress Classic 2025-04-23 00:36:05+00:00
# 2            30                      Day of Defeat 2025-04-23 00:36:20+00:00
# 3            40                 Deathmatch Classic 2025-04-23 00:36:10+00:00
# 4            50          Half-Life: Opposing Force 2025-04-23 00:35:39+00:00
# ...         ...                                ...                       ...
# 208024  4283320  Five Nights At Monkeys: Flat Mode 2026-01-04 01:28:06+00:00
# 208025  4283390              EYEVIRUS: Compression 2026-01-02 19:25:02+00:00
# 208026  4283740                       Space Direct 2026-01-03 07:39:52+00:00
# 208027  4284950                       Flask & Fury 2026-01-03 21:11:42+00:00
# 208028  4285180                         DREADMARCH 2026-01-04 23:00:47+00:00
#
#         price_change_number
# 0                  32873429
# 1                  32873429
# 2                  32873429
# 3                  32873429
# 4                  32873429
# ...                     ...
# 208024             32967136
# 208025                    0
# 208026                    0
# 208027                    0
# 208028                    0
#
# [208029 rows x 4 columns]

# %%
print(apps_df['last_modified'].min(), '->', apps_df['last_modified'].max())
# Out:
# 2015-11-12 17:55:14+00:00 -> 2026-01-05 14:01:30+00:00

# %%
apps_df["last_modified"].dt.date.value_counts().sort_index()
# Out:
# last_modified
# 2015-11-12    1336
# 2015-11-13     349
# 2015-11-14       1
# 2015-11-15       2
# 2015-11-16       3
#               ...
# 2026-01-01     465
# 2026-01-02     649
# 2026-01-03     722
# 2026-01-04     681
# 2026-01-05     494
# Name: count, Length: 3664, dtype: int64

# %%
apps_df["last_modified"].dt.to_period("M").value_counts().sort_index()
# Out:
# C:\Users\Kiko\AppData\Local\Temp\ipykernel_29224\2747548103.py:1: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   apps_df["last_modified"].dt.to_period("M").value_counts().sort_index()
# last_modified
# 2015-11     1740
# 2015-12      110
# 2016-01       97
# 2016-02      100
# 2016-03      120
#            ...
# 2025-09     6833
# 2025-10     9332
# 2025-11    11578
# 2025-12    20229
# 2026-01     3011
# Freq: M, Name: count, Length: 123, dtype: int64

# %% [markdown]
# ## 2. Steam Store app details

# %%
store_df = pd.read_parquet(STORE_PARQUET)
print('Store details shape (rows, cols):', store_df.shape)
print(store_df.info())

store_df.head()
# Out:
# Store details shape (rows, cols): (5912, 133)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5912 entries, 0 to 5911
# Columns: 133 entries, type to ratings.gmedia.rating
# dtypes: bool(5), float64(8), int64(2), string(118)
# memory usage: 5.8 MB
# None
#    type                       name  steam_appid required_age  is_free  \
# 0  game             Counter-Strike           10            0    False
# 1  game      Team Fortress Classic           20            0    False
# 2  game              Day of Defeat           30            0    False
# 3  game         Deathmatch Classic           40            0    False
# 4  game  Half-Life: Opposing Force           50            0    False
#
#                                 detailed_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# 4                    English, French, German, Korean
#
#                                         header_image  ...  \
# 0  https://shared.akamai.steamstatic.com/store_it...  ...
# 1  https://shared.akamai.steamstatic.com/store_it...  ...
# 2  https://shared.akamai.steamstatic.com/store_it...  ...
# 3  https://shared.akamai.steamstatic.com/store_it...  ...
# 4  https://shared.akamai.steamstatic.com/store_it...  ...
#
#   ratings.cero.required_age ratings.cero.descriptors ratings.fpb.descriptors  \
# 0                      <NA>                     <NA>                    <NA>
# 1                      <NA>                     <NA>                    <NA>
# 2                      <NA>                     <NA>                    <NA>
# 3                      <NA>                     <NA>                    <NA>
# 4                      <NA>                     <NA>                    <NA>
#
#   ratings.bbfc.descriptors ratings.crl.descriptors  \
# 0                     <NA>                    <NA>
# 1                     <NA>                    <NA>
# 2                     <NA>                    <NA>
# 3                     <NA>                    <NA>
# 4                     <NA>                    <NA>
#
#   price_overview.recurring_sub price_overview.recurring_sub_desc  \
# 0                          NaN                              <NA>
# 1                          NaN                              <NA>
# 2                          NaN                              <NA>
# 3                          NaN                              <NA>
# 4                          NaN                              <NA>
#
#   ratings.mda.descriptors ratings.cadpa.descriptors ratings.gmedia.rating
# 0                    <NA>                      <NA>                  <NA>
# 1                    <NA>                      <NA>                  <NA>
# 2                    <NA>                      <NA>                  <NA>
# 3                    <NA>                      <NA>                  <NA>
# 4                    <NA>                      <NA>                  <NA>
#
# [5 rows x 133 columns]

# %% [markdown]
# ## 3. Join Web app list and Store details

# %%
merged = apps_df.merge(store_df,on='appid',how='left',suffixes=('_web', '_store'))
print('Merged shape (rows, cols):', merged.shape)
print('Rows with store details:', merged['name_store'].notna().sum() if 'name_store' in merged.columns else 'n/a')
# Out:
# Merged shape (rows, cols): (208029, 136)
# Rows with store details: 5912

# %%
merged
# Out:
#           appid                           name_web             last_modified  \
# 0            10                     Counter-Strike 2025-04-23 00:36:12+00:00
# 1            20              Team Fortress Classic 2025-04-23 00:36:05+00:00
# 2            30                      Day of Defeat 2025-04-23 00:36:20+00:00
# 3            40                 Deathmatch Classic 2025-04-23 00:36:10+00:00
# 4            50          Half-Life: Opposing Force 2025-04-23 00:35:39+00:00
# ...         ...                                ...                       ...
# 208024  4283320  Five Nights At Monkeys: Flat Mode 2026-01-04 01:28:06+00:00
# 208025  4283390              EYEVIRUS: Compression 2026-01-02 19:25:02+00:00
# 208026  4283740                       Space Direct 2026-01-03 07:39:52+00:00
# 208027  4284950                       Flask & Fury 2026-01-03 21:11:42+00:00
# 208028  4285180                         DREADMARCH 2026-01-04 23:00:47+00:00
#
#         price_change_number  type                 name_store  steam_appid  \
# 0                  32873429  game             Counter-Strike         10.0
# 1                  32873429  game      Team Fortress Classic         20.0
# 2                  32873429  game              Day of Defeat         30.0
# 3                  32873429  game         Deathmatch Classic         40.0
# 4                  32873429  game  Half-Life: Opposing Force         50.0
# ...                     ...   ...                        ...          ...
# 208024             32967136  <NA>                       <NA>          NaN
# 208025                    0  <NA>                       <NA>          NaN
# 208026                    0  <NA>                       <NA>          NaN
# 208027                    0  <NA>                       <NA>          NaN
# 208028                    0  <NA>                       <NA>          NaN
#
#        required_age is_free  \
# 0                 0   False
# 1                 0   False
# 2                 0   False
# 3                 0   False
# 4                 0   False
# ...             ...     ...
# 208024         <NA>     NaN
# 208025         <NA>     NaN
# 208026         <NA>     NaN
# 208027         <NA>     NaN
# 208028         <NA>     NaN
#
#                                      detailed_description  ...  \
# 0       Play the world's number 1 online action game. ...  ...
# 1       One of the most popular online action games of...  ...
# 2       Enlist in an intense brand of Axis vs. Allied ...  ...
# 3       Enjoy fast-paced multiplayer gaming with Death...  ...
# 4       Return to the Black Mesa Research Facility as ...  ...
# ...                                                   ...  ...
# 208024                                               <NA>  ...
# 208025                                               <NA>  ...
# 208026                                               <NA>  ...
# 208027                                               <NA>  ...
# 208028                                               <NA>  ...
#
#        ratings.cero.required_age ratings.cero.descriptors  \
# 0                           <NA>                     <NA>
# 1                           <NA>                     <NA>
# 2                           <NA>                     <NA>
# 3                           <NA>                     <NA>
# 4                           <NA>                     <NA>
# ...                          ...                      ...
# 208024                      <NA>                     <NA>
# 208025                      <NA>                     <NA>
# 208026                      <NA>                     <NA>
# 208027                      <NA>                     <NA>
# 208028                      <NA>                     <NA>
#
#        ratings.fpb.descriptors ratings.bbfc.descriptors  \
# 0                         <NA>                     <NA>
# 1                         <NA>                     <NA>
# 2                         <NA>                     <NA>
# 3                         <NA>                     <NA>
# 4                         <NA>                     <NA>
# ...                        ...                      ...
# 208024                    <NA>                     <NA>
# 208025                    <NA>                     <NA>
# 208026                    <NA>                     <NA>
# 208027                    <NA>                     <NA>
# 208028                    <NA>                     <NA>
#
#        ratings.crl.descriptors price_overview.recurring_sub  \
# 0                         <NA>                          NaN
# 1                         <NA>                          NaN
# 2                         <NA>                          NaN
# 3                         <NA>                          NaN
# 4                         <NA>                          NaN
# ...                        ...                          ...
# 208024                    <NA>                          NaN
# 208025                    <NA>                          NaN
# 208026                    <NA>                          NaN
# 208027                    <NA>                          NaN
# 208028                    <NA>                          NaN
#
#        price_overview.recurring_sub_desc ratings.mda.descriptors  \
# 0                                   <NA>                    <NA>
# 1                                   <NA>                    <NA>
# 2                                   <NA>                    <NA>
# 3                                   <NA>                    <NA>
# 4                                   <NA>                    <NA>
# ...                                  ...                     ...
# 208024                              <NA>                    <NA>
# 208025                              <NA>                    <NA>
# 208026                              <NA>                    <NA>
# 208027                              <NA>                    <NA>
# 208028                              <NA>                    <NA>
#
#        ratings.cadpa.descriptors ratings.gmedia.rating
# 0                           <NA>                  <NA>
# 1                           <NA>                  <NA>
# 2                           <NA>                  <NA>
# 3                           <NA>                  <NA>
# 4                           <NA>                  <NA>
# ...                          ...                   ...
# 208024                      <NA>                  <NA>
# 208025                      <NA>                  <NA>
# 208026                      <NA>                  <NA>
# 208027                      <NA>                  <NA>
# 208028                      <NA>                  <NA>
#
# [208029 rows x 136 columns]

# %% [markdown]
# ## 4. Next EDA ideas
#
# Some directions you can extend from here:
#
# - Plot distributions (owners, price, discount, required_age) once more columns are available.
# - Look at correlations between basic numeric features.
# - Parse and explode tag/genre columns from the store data string fields.
# - Build feature tables ("silver" / "gold") for ML experiments (success prediction, recommendations, etc.).
